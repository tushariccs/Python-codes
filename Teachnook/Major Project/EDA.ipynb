# %%
import pandas as pd
import numpy as np

# %%
cand = pd.read_csv('covid_worldwide.csv')
cand
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
#type of the df
type(cand)
# Out:
# pandas.core.frame.DataFrame

# %%
#defines the datatypes of element in the column
cand.dtypes

#size of the dataset
cand.size

#Info of the dataset using info method

cand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    object
#  3   Total Deaths     225 non-null    object
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 14.6+ KB

# %%
#To check null values are there
cand.isnull().sum()
# Out:
# Serial Number       0
# Country             0
# Total Cases         0
# Total Deaths        6
# Total Recovered    21
# Active Cases       19
# Total Test         18
# Population          3
# dtype: int64

# %%
#Slicing the data with column using iloc
print (cand.iloc[0:20,2:4])
# Out:
#     Total Cases Total Deaths
# 0   104,196,861    1,132,935
# 1    44,682,784      530,740
# 2    39,524,311      164,233
# 3    37,779,833      165,711
# 4    36,824,580      697,074
# 5    32,588,442       68,399
# 6    30,197,066       33,486
# 7    25,453,789      186,833
# 8    24,274,361      204,171
# 9    21,958,696      395,108
# 10   17,042,722      101,492
# 11   13,731,478      118,434
# 12   11,526,508       43,186
# 13   11,295,446       18,615
# 14   10,037,135      130,421
# 15    9,569,611       16,356
# 16    8,582,500       22,989
# 17    7,564,350      144,749
# 18    7,368,252      332,198
# 19    6,730,289      160,817

# %%
cand['Total Deaths'].nunique()
# Out:
# 213

# %%
cand.groupby('Country').size()
# Out:
# Country
# Afghanistan          1
# Albania              1
# Algeria              1
# Andorra              1
# Angola               1
#                     ..
# Wallis and Futuna    1
# Western Sahara       1
# Yemen                1
# Zambia               1
# Zimbabwe             1
# Length: 231, dtype: int64

# %%
#graph
import matplotlib.pyplot as pl
a = cand['Total Deaths'].head(10)
b = cand['Total Cases'].head(10)
pl.bar(a,b,color=['Violet','Indigo','Blue'])
pl.grid()

# %%
#To define first five and last five data of the above dataset

#Gives the last five elements of the dataset

(cand.tail()) 

#Gives the first five elements of the dataset

(cand.head())
# Out:
#    Serial Number  Country  Total Cases Total Deaths Total Recovered  \
# 0              1      USA  104,196,861    1,132,935     101,322,779
# 1              2    India   44,682,784      530,740      44,150,289
# 2              3   France   39,524,311      164,233      39,264,546
# 3              4  Germany   37,779,833      165,711      37,398,100
# 4              5   Brazil   36,824,580      697,074      35,919,372
#
#   Active Cases     Total Test     Population
# 0    1,741,147  1,159,832,679    334,805,269
# 1        1,755    915,265,788  1,406,631,776
# 2       95,532    271,490,188     65,584,518
# 3      216,022    122,332,384     83,883,596
# 4      208,134     63,776,166    215,353,593

# %%
#Describe is used to define the count,mean,std and various properties
cand.describe()
# Out:
#        Serial Number
# count     231.000000
# mean      116.000000
# std        66.828138
# min         1.000000
# 25%        58.500000
# 50%       116.000000
# 75%       173.500000
# max       231.000000

# %%
 #Using value_counts
b = cand['Total Cases'].value_counts()
b
cand
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
#Create  a new dataframe
cand
df_new = cand[['Total Cases','Total Deaths']]
# df_new['Total Cases'] = df_new['Total Cases'].astype(int)
# df_new['Total Deaths'] = df_new['Total Deaths'].astype(int)
a = df_new['Total Cases'].head(20).str.replace(',','')
b = df_new['Total Deaths'].head(20).str.replace(',','')
# a = df_new['Total Deaths'].replace(',','')
# for i in range(0,10,1):
#     b[i].split(',',' ')
print(a)
print(b)
# df_new.dtypes
# a
# Out:
# 0     104196861
# 1      44682784
# 2      39524311
# 3      37779833
# 4      36824580
# 5      32588442
# 6      30197066
# 7      25453789
# 8      24274361
# 9      21958696
# 10     17042722
# 11     13731478
# 12     11526508
# 13     11295446
# 14     10037135
# 15      9569611
# 16      8582500
# 17      7564350
# 18      7368252
# 19      6730289
# Name: Total Cases, dtype: object
# 0     1132935
# 1      530740
# 2      164233
# 3      165711
# 4      697074
# 5       68399
# 6       33486
# 7      186833
# 8      204171
# 9      395108
# 10     101492
# 11     118434
# 12      43186
# 13      18615
# 14     130421
# 15      16356
# 16      22989
# 17     144749
# 18     332198
# 19     160817
# Name: Total Deaths, dtype: object

# %%
#Visualisation
import matplotlib.pyplot as plt

plt.figure(figsize=(25,5))
plt.plot(a,b)

# plt.scatter(a,b)

# plt.subplots_adjust(bottom=spacing)
plt.grid()

# %%
# Out:
# array([['1,132,935'],
#        ['530,740'],
#        ['164,233'],
#        ['165,711'],
#        ['697,074'],
#        ['68,399'],
#        ['33,486'],
#        ['186,833'],
#        ['204,171'],
#        ['395,108'],
#        ['101,492'],
#        ['118,434'],
#        ['43,186'],
#        ['18,615'],
#        ['130,421'],
#        ['16,356'],
#        ['22,989'],
#        ['144,749'],
#        ['332,198'],
#        ['160,817']], dtype=object)

# %%
#Classifier,Regressor,Cluster
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14028\1904801846.py in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(x,y)
#
# e:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# e:\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
y_predict = model.predict(a)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13584\2504317208.py in <module>
# ----> 1 y_predict = model.predict(a)
#
# e:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# e:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# e:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# ...
